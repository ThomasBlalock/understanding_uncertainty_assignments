# %% [markdown]
# # Assignment 7
# ### Do any five.

# %% [markdown]
# ## 6.
# - Use the Taylor series expansions
# $$
# F(x+h) = F(x) + hf(x) + \frac{h^2}{2}f'(x) + O(h^3)
# $$
# and
# $$
# F(x-h) = F(x) - h f(x) + \frac{h^2}{2} f'(x)+ O(h^3)
# $$
# to show that
# $$
# \mathbb{E}[\hat{f}_{X,h}(x)] = \frac{F(x+h)-F(x-h)}{2h} = f(x) + O(h^2),
# $$
# so the **bias** of the KDE is $O(h^2)$, unlike the ECDF, for which $\mathbb{E}[\hat{F}(x)] = F(x)$.

# %% [markdown]
# (1) [F(x+h) - F(x-h)] / 2h
#
# (2) [ [F(x) + h*f(x) + (h^2*f'(x)) + O(h^3)] - [F(x) - h*f(x) + (h^2*f'(x)) + O(h^3)] ] / 2h
#
#         a       b       c       d      a    b         c         d
#
# a, c, and d terms cancel out, left with...
#
# (3) 2h*f(x) / 2h
#
# (4) f(x) = f(x) + O(h^2)
#
# Note: O(h^2) is an error term on the order of the power of 2.
